# %% [markdown]
# # Dependências

# %%
import pandas as pd
import numpy as np
from glob import glob

# %% [markdown]
# # Dados

# %% [markdown]
# ### Dados de Treinamento

# %%
data_train = pd.read_csv("./data/train.csv", sep=',')
data_train.head(5)
# Out:
#    Id  field  age  type  harvest_year  harvest_month  production
# 0   0      0   19     5          2004              1    0.064071
# 1   1      0   19     5          2004              2    0.047658
# 2   2      0   19     5          2004              3    0.016866
# 3   3      0   19     5          2004              4    0.025525
# 4   4      0   19     5          2004              5    0.047690

# %% [markdown]
# ## Treinamento + Fields

# %%
fields = [ field for field in glob('./data/field**.csv')]

# %%
data_fields = []
for field in fields:
    field_ = pd.read_csv(field, sep=',')
    field_['field'] = int(field.split('-')[1].split('.')[0])
    data_fields.append(field_)
data_fields = pd.concat(data_fields)

# %%
data_train_fields = data_train.merge(data_fields, left_on=['field','harvest_year', 'harvest_month'], right_on=['field', 'year', 'month'])
data_train_fields.to_csv('data/data_train_fields.csv', sep=',', encoding='utf-8')
data_train_fields.head(5)
# Out:
#      Id  field  age  type  harvest_year  harvest_month  production  month  \
# 0     0      0   19     5          2004              1    0.064071      1
# 1  1532      0   13     2          2004              1    0.283228      1
# 2  4204      0    4     5          2004              1    0.106263      1
# 3     1      0   19     5          2004              2    0.047658      2
# 4  1533      0   13     2          2004              2    0.182068      2
#
#    year  temperature  dewpoint  windspeed  Soilwater_L1  Soilwater_L2  \
# 0  2004       26.132    24.661     1.8766       0.35274       0.35192
# 1  2004       26.132    24.661     1.8766       0.35274       0.35192
# 2  2004       26.132    24.661     1.8766       0.35274       0.35192
# 3  2004       25.295    24.401     1.9206       0.36361       0.36376
# 4  2004       25.295    24.401     1.9206       0.36361       0.36376
#
#    Soilwater_L3  Soilwater_L4  Precipitation
# 0       0.34844       0.33385         360.91
# 1       0.34844       0.33385         360.91
# 2       0.34844       0.33385         360.91
# 3       0.36411       0.36357         484.67
# 4       0.36411       0.36357         484.67

# %% [markdown]
# ## Treinamento + Fields + Soil

# %%
data_soil = pd.read_csv("data/soil_data.csv", sep=',')

# %%
data_train_fields_soil = data_train_fields.merge(data_soil, on='field')
data_train_fields_soil.to_csv('data/data_train_fields_soil.csv', sep=',', encoding='utf-8')
data_train_fields_soil.head(5)
# Out:
#      Id  field  age  type  harvest_year  harvest_month  production  month  \
# 0     0      0   19     5          2004              1    0.064071      1
# 1  1532      0   13     2          2004              1    0.283228      1
# 2  4204      0    4     5          2004              1    0.106263      1
# 3     1      0   19     5          2004              2    0.047658      2
# 4  1533      0   13     2          2004              2    0.182068      2
#
#    year  temperature     ...      SLTPPT_sl5  SLTPPT_sl6  SLTPPT_sl7  \
# 0  2004       26.132     ...              22          22          23
# 1  2004       26.132     ...              22          22          23
# 2  2004       26.132     ...              22          22          23
# 3  2004       25.295     ...              22          22          23
# 4  2004       25.295     ...              22          22          23
#
#    SNDPPT_sl1  SNDPPT_sl2  SNDPPT_sl3  SNDPPT_sl4  SNDPPT_sl5  SNDPPT_sl6  \
# 0          44          45          44          39          38          37
# 1          44          45          44          39          38          37
# 2          44          45          44          39          38          37
# 3          44          45          44          39          38          37
# 4          44          45          44          39          38          37
#
#    SNDPPT_sl7
# 0          36
# 1          36
# 2          36
# 3          36
# 4          36
#
# [5 rows x 89 columns]

# %% [markdown]
# ### Dados de testes

# %%
data_test = pd.read_csv('data/test.csv', sep=',')
data_test.head(5)
# Out:
#      Id  field  age  type  harvest_year  harvest_month
# 0  5243      0   27     5          2012              1
# 1  5244      0   27     5          2012              2
# 2  5245      0   27     5          2012              3
# 3  5246      0   27     5          2012              4
# 4  5247      0   27     5          2012              5

# %% [markdown]
# ### Testes + Fields

# %%
data_test_fields = data_train.merge(data_fields, left_on=['field','harvest_year', 'harvest_month'], right_on=['field', 'year', 'month'])
data_test_fields.to_csv('data/data_test_fields.csv', sep=',', encoding='utf-8')
data_test_fields.head(5)
# Out:
#      Id  field  age  type  harvest_year  harvest_month  production  month  \
# 0     0      0   19     5          2004              1    0.064071      1
# 1  1532      0   13     2          2004              1    0.283228      1
# 2  4204      0    4     5          2004              1    0.106263      1
# 3     1      0   19     5          2004              2    0.047658      2
# 4  1533      0   13     2          2004              2    0.182068      2
#
#    year  temperature  dewpoint  windspeed  Soilwater_L1  Soilwater_L2  \
# 0  2004       26.132    24.661     1.8766       0.35274       0.35192
# 1  2004       26.132    24.661     1.8766       0.35274       0.35192
# 2  2004       26.132    24.661     1.8766       0.35274       0.35192
# 3  2004       25.295    24.401     1.9206       0.36361       0.36376
# 4  2004       25.295    24.401     1.9206       0.36361       0.36376
#
#    Soilwater_L3  Soilwater_L4  Precipitation
# 0       0.34844       0.33385         360.91
# 1       0.34844       0.33385         360.91
# 2       0.34844       0.33385         360.91
# 3       0.36411       0.36357         484.67
# 4       0.36411       0.36357         484.67

# %% [markdown]
# ### Teste + Fields + Soil

# %%
data_test_fields_soil = data_test_fields.merge(data_soil, on='field')
data_test_fields_soil.to_csv('data/data_test_fields_soil.csv', sep=',', encoding='utf-8')
data_test_fields_soil.head(5)
# Out:
#      Id  field  age  type  harvest_year  harvest_month  production  month  \
# 0     0      0   19     5          2004              1    0.064071      1
# 1  1532      0   13     2          2004              1    0.283228      1
# 2  4204      0    4     5          2004              1    0.106263      1
# 3     1      0   19     5          2004              2    0.047658      2
# 4  1533      0   13     2          2004              2    0.182068      2
#
#    year  temperature     ...      SLTPPT_sl5  SLTPPT_sl6  SLTPPT_sl7  \
# 0  2004       26.132     ...              22          22          23
# 1  2004       26.132     ...              22          22          23
# 2  2004       26.132     ...              22          22          23
# 3  2004       25.295     ...              22          22          23
# 4  2004       25.295     ...              22          22          23
#
#    SNDPPT_sl1  SNDPPT_sl2  SNDPPT_sl3  SNDPPT_sl4  SNDPPT_sl5  SNDPPT_sl6  \
# 0          44          45          44          39          38          37
# 1          44          45          44          39          38          37
# 2          44          45          44          39          38          37
# 3          44          45          44          39          38          37
# 4          44          45          44          39          38          37
#
#    SNDPPT_sl7
# 0          36
# 1          36
# 2          36
# 3          36
# 4          36
#
# [5 rows x 89 columns]
